# %% [markdown]
# #### Getting the source code of 'List of postal codes of Canada: M' from wikipedia

# %%
import requests
url = 'https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M'

# %%
source = requests.get(url)

# %% [markdown]
# Import the **beautifulsoup** for web scrapping

# %%
import bs4
soup = bs4.BeautifulSoup(source.text, "lxml")

# %% [markdown]
# #### We will find all tables in the source using `find_all` method and use pandas'  `read_html()` function to convert the html code of first table (which is the one we are looking for) in pandas dataframe

# %%
import pandas as pd
table = soup.find_all('table')
df = pd.read_html(str(table))[0]
df.head(10)
# Out:
#   Postal Code           Borough                                Neighbourhood
# 0         M1A      Not assigned                                 Not assigned
# 1         M2A      Not assigned                                 Not assigned
# 2         M3A        North York                                    Parkwoods
# 3         M4A        North York                             Victoria Village
# 4         M5A  Downtown Toronto                    Regent Park, Harbourfront
# 5         M6A        North York             Lawrence Manor, Lawrence Heights
# 6         M7A  Downtown Toronto  Queen's Park, Ontario Provincial Government
# 7         M8A      Not assigned                                 Not assigned
# 8         M9A         Etobicoke      Islington Avenue, Humber Valley Village
# 9         M1B       Scarborough                               Malvern, Rouge

# %% [markdown]
# #### We noticed above that there are cells with a borough that is *Not assigned*. We will remove such cells

# %%
df[df['Borough']== 'Not assigned'].any(axis = 0) #checking if there are cells with Borough Not Assigned
# Out:
# Postal Code      True
# Borough          True
# Neighbourhood    True
# dtype: bool

# %% [markdown]
# #### Let us drop the rows with Borough Not Assigned from our dataframe df

# %%
df.drop(df[df['Borough']== 'Not assigned'].index, inplace = True) 
df.head(15)
# Out:
#    Postal Code           Borough  \
# 2          M3A        North York
# 3          M4A        North York
# 4          M5A  Downtown Toronto
# 5          M6A        North York
# 6          M7A  Downtown Toronto
# 8          M9A         Etobicoke
# 9          M1B       Scarborough
# 11         M3B        North York
# 12         M4B         East York
# 13         M5B  Downtown Toronto
# 14         M6B        North York
# 17         M9B         Etobicoke
# 18         M1C       Scarborough
# 20         M3C        North York
# 21         M4C         East York
#
#                                         Neighbourhood
# 2                                           Parkwoods
# 3                                    Victoria Village
# 4                           Regent Park, Harbourfront
# 5                    Lawrence Manor, Lawrence Heights
# 6         Queen's Park, Ontario Provincial Government
# 8             Islington Avenue, Humber Valley Village
# 9                                      Malvern, Rouge
# 11                                          Don Mills
# 12                    Parkview Hill, Woodbine Gardens
# 13                           Garden District, Ryerson
# 14                                          Glencairn
# 17  West Deane Park, Princess Gardens, Martin Grov...
# 18             Rouge Hill, Port Union, Highland Creek
# 20                                          Don Mills
# 21                                   Woodbine Heights

# %% [markdown]
# #### We noticed that our index have changed, so let us reset index:

# %%
df.reset_index(drop = True, inplace = True) 
df.head(15)
# Out:
#    Postal Code           Borough  \
# 0          M3A        North York
# 1          M4A        North York
# 2          M5A  Downtown Toronto
# 3          M6A        North York
# 4          M7A  Downtown Toronto
# 5          M9A         Etobicoke
# 6          M1B       Scarborough
# 7          M3B        North York
# 8          M4B         East York
# 9          M5B  Downtown Toronto
# 10         M6B        North York
# 11         M9B         Etobicoke
# 12         M1C       Scarborough
# 13         M3C        North York
# 14         M4C         East York
#
#                                         Neighbourhood
# 0                                           Parkwoods
# 1                                    Victoria Village
# 2                           Regent Park, Harbourfront
# 3                    Lawrence Manor, Lawrence Heights
# 4         Queen's Park, Ontario Provincial Government
# 5             Islington Avenue, Humber Valley Village
# 6                                      Malvern, Rouge
# 7                                           Don Mills
# 8                     Parkview Hill, Woodbine Gardens
# 9                            Garden District, Ryerson
# 10                                          Glencairn
# 11  West Deane Park, Princess Gardens, Martin Grov...
# 12             Rouge Hill, Port Union, Highland Creek
# 13                                          Don Mills
# 14                                   Woodbine Heights

# %% [markdown]
# #### We will check if a cell has a borough but a 'Not assigned'  neighborhood

# %%
#len(df[df['Neighbourhood']== 'Not assigned'])

# %%
df[df['Neighbourhood']== 'Not assigned'].any(axis = 0)
# Out:
# Postal Code      False
# Borough          False
# Neighbourhood    False
# dtype: bool

# %% [markdown]
# We find that there are no such cell, so we need do nothing.

# %% [markdown]
# #### Let's find the shape of data frame:

# %%
print(' The shape of our dataframe is {}'.format(df.shape))
# Out:
#  The shape of our dataframe is (103, 3)

# %%
pip install geocoder
# Out:
# Requirement already satisfied: geocoder in c:\users\pragyan\anaconda3\lib\site-packages (1.38.1)
# Requirement already satisfied: ratelim in c:\users\pragyan\anaconda3\lib\site-packages (from geocoder) (0.1.6)
# Requirement already satisfied: future in c:\users\pragyan\anaconda3\lib\site-packages (from geocoder) (0.18.2)
# Requirement already satisfied: click in c:\users\pragyan\anaconda3\lib\site-packages (from geocoder) (7.1.2)
# Requirement already satisfied: requests in c:\users\pragyan\anaconda3\lib\site-packages (from geocoder) (2.25.1)
# Requirement already satisfied: six in c:\users\pragyan\anaconda3\lib\site-packages (from geocoder) (1.15.0)
# Requirement already satisfied: decorator in c:\users\pragyan\anaconda3\lib\site-packages (from ratelim->geocoder) (4.4.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\pragyan\anaconda3\lib\site-packages (from requests->geocoder) (2020.12.5)
# Requirement already satisfied: chardet<5,>=3.0.2 in c:\users\pragyan\anaconda3\lib\site-packages (from requests->geocoder) (4.0.0)
# Requirement already satisfied: idna<3,>=2.5 in c:\users\pragyan\anaconda3\lib\site-packages (from requests->geocoder) (2.10)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\pragyan\anaconda3\lib\site-packages (from requests->geocoder) (1.26.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
latlng_df = pd.read_csv('Geospatial_Coordinates.csv')

# %%
df.merge(latlng_df, left_on = 'Postal Code', right_on = 'Postal Code')
# Out:
#     Postal Code           Borough  \
# 0           M3A        North York
# 1           M4A        North York
# 2           M5A  Downtown Toronto
# 3           M6A        North York
# 4           M7A  Downtown Toronto
# ..          ...               ...
# 98          M8X         Etobicoke
# 99          M4Y  Downtown Toronto
# 100         M7Y      East Toronto
# 101         M8Y         Etobicoke
# 102         M8Z         Etobicoke
#
#                                          Neighbourhood   Latitude  Longitude
# 0                                            Parkwoods  43.753259 -79.329656
# 1                                     Victoria Village  43.725882 -79.315572
# 2                            Regent Park, Harbourfront  43.654260 -79.360636
# 3                     Lawrence Manor, Lawrence Heights  43.718518 -79.464763
# 4          Queen's Park, Ontario Provincial Government  43.662301 -79.389494
# ..                                                 ...        ...        ...
# 98       The Kingsway, Montgomery Road, Old Mill North  43.653654 -79.506944
# 99                                Church and Wellesley  43.665860 -79.383160
# 100  Business reply mail Processing Centre, South C...  43.662744 -79.321558
# 101  Old Mill South, King's Mill Park, Sunnylea, Hu...  43.636258 -79.498509
# 102  Mimico NW, The Queensway West, South of Bloor,...  43.628841 -79.520999
#
# [103 rows x 5 columns]
